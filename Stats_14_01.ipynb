# %% [markdown]
# <a href="https://colab.research.google.com/github/michelleabraham-git/Stats_minor/blob/main/Stats_14_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
print("test")
# Out:
# test

# %% [markdown]
# yo hello wassupppp
#
# > blockqoute
# yo hey lol

# %% [markdown]
# im putting in a message

# %%
a = [2, 2, 3, 4, 5]
plt.plot(a)
# plt is the name given to the package matplotlib after we imported the package.

# %%
a = 2 + 4
b = 3 + 5
print(a)
print(b)
print(a*b)
# Out:
# 6
# 8
# 48
